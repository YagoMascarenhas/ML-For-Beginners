# %% [markdown]
# # Regression 02 - Data
#
# ### What do we do here?
#
# Here we analyse the [pumpkin dataset](../data/US-pumpkins.csv) in the data folder
#
# ### The libraries
#
# - **Pandas** - an open source for data analysis and manipulation

# %%
# Importing Pandas and pyplot
import pandas as pd
import matplotlib.pyplot as plt
# Read the csv file
pumpkins = pd.read_csv("../data/US-pumpkins.csv")
# Prints the first five of rows in the dataset
pumpkins.head()
# Out:
#    City Name Type       Package      Variety Sub Variety  Grade     Date  \
# 0  BALTIMORE  NaN  24 inch bins          NaN         NaN    NaN  4/29/17
# 1  BALTIMORE  NaN  24 inch bins          NaN         NaN    NaN   5/6/17
# 2  BALTIMORE  NaN  24 inch bins  HOWDEN TYPE         NaN    NaN  9/24/16
# 3  BALTIMORE  NaN  24 inch bins  HOWDEN TYPE         NaN    NaN  9/24/16
# 4  BALTIMORE  NaN  24 inch bins  HOWDEN TYPE         NaN    NaN  11/5/16
#
#    Low Price  High Price  Mostly Low  ...  Unit of Sale Quality Condition  \
# 0      270.0       280.0       270.0  ...           NaN     NaN       NaN
# 1      270.0       280.0       270.0  ...           NaN     NaN       NaN
# 2      160.0       160.0       160.0  ...           NaN     NaN       NaN
# 3      160.0       160.0       160.0  ...           NaN     NaN       NaN
# 4       90.0       100.0        90.0  ...           NaN     NaN       NaN
#
#   Appearance Storage  Crop Repack  Trans Mode  Unnamed: 24  Unnamed: 25
# ...

# %%
# Filter by selecting only the Package with the string "bushel"
pumpkins = pumpkins[pumpkins["Package"].str.contains("bushel", case=True, regex=True)]
pumpkins
# Out:
#       City Name Type               Package    Variety Sub Variety  Grade  \
# 70    BALTIMORE  NaN  1 1/9 bushel cartons   PIE TYPE         NaN    NaN
# 71    BALTIMORE  NaN  1 1/9 bushel cartons   PIE TYPE         NaN    NaN
# 72    BALTIMORE  NaN  1 1/9 bushel cartons   PIE TYPE         NaN    NaN
# 73    BALTIMORE  NaN  1 1/9 bushel cartons   PIE TYPE         NaN    NaN
# 74    BALTIMORE  NaN  1 1/9 bushel cartons   PIE TYPE         NaN    NaN
# ...         ...  ...                   ...        ...         ...    ...
# 1738  ST. LOUIS  NaN    1/2 bushel cartons  MINIATURE   FLAT TYPE    NaN
# 1739  ST. LOUIS  NaN    1/2 bushel cartons  MINIATURE   FLAT TYPE    NaN
# 1740  ST. LOUIS  NaN    1/2 bushel cartons  MINIATURE   FLAT TYPE    NaN
# 1741  ST. LOUIS  NaN    1/2 bushel cartons  MINIATURE   FLAT TYPE    NaN
# 1742  ST. LOUIS  NaN    1/2 bushel cartons  MINIATURE   FLAT TYPE    NaN
#
#          Date  Low Price  High Price  Mostly Low  ...  Unit of Sale Quality  \
# ...

# %%
# Check if there is null (missing) data in the dataset
pumpkins.isnull().sum()
# Out:
# City Name            0
# Type               406
# Package              0
# Variety              0
# Sub Variety        167
# Grade              415
# Date                 0
# Low Price            0
# High Price           0
# Mostly Low          24
# Mostly High         24
# Origin               0
# Origin District    396
# Item Size          114
# Color              145
# Environment        415
# Unit of Sale       404
# Quality            415
# Condition          415
# Appearance         415
# Storage            415
# Crop               415
# Repack               0
# Trans Mode         415
# Unnamed: 24        415
# Unnamed: 25        391
# dtype: int64

# %%
# Selecting only the columns we need
# The loc function extracts a part of the dataset. The first parameter is the group of rows you want and the second is a group of columns
columns_to_select = ["Package", "Low Price", "High Price", "Date"]
pumpkins = pumpkins.loc[:, columns_to_select]
pumpkins.head()
# Out:
#                  Package  Low Price  High Price     Date
# 70  1 1/9 bushel cartons       15.0        15.0  9/24/16
# 71  1 1/9 bushel cartons       18.0        18.0  9/24/16
# 72  1 1/9 bushel cartons       18.0        18.0  10/1/16
# 73  1 1/9 bushel cartons       17.0        17.0  10/1/16
# 74  1 1/9 bushel cartons       15.0        15.0  10/8/16

# %%
# Calculates the average price of a punpkin
price = (pumpkins["Low Price"] + pumpkins["High Price"]) / 2
# Convert the Date column to only show the month
month = pd.DatetimeIndex(pumpkins["Date"]).month
print(month)
# Out:
# Index([ 9,  9, 10, 10, 10, 10, 10, 10, 10, 10,
#        ...
#         9,  9,  9,  9,  9,  9,  9,  9,  9,  9],
#       dtype='int32', name='Date', length=415)

# %%
# Copy the converted data to a new dataframe
new_pumpkins = pd.DataFrame({
    "Month": month,
    "Package": pumpkins["Package"],
    "Low Price": pumpkins["Low Price"],
    "High Price": pumpkins["High Price"],
    "Price": price
})

# %%
# Normalise the prices to show the price for bushel
new_pumpkins.loc[new_pumpkins["Package"].str.contains("1 1/9"), "Price"] = price/(1 + 1/9)
new_pumpkins.loc[new_pumpkins["Package"].str.contains("1/2"), "Price"] = price/(1/2)
new_pumpkins
# Out:
#       Month               Package  Low Price  High Price  Price
# 70        9  1 1/9 bushel cartons      15.00        15.0  13.50
# 71        9  1 1/9 bushel cartons      18.00        18.0  16.20
# 72       10  1 1/9 bushel cartons      18.00        18.0  16.20
# 73       10  1 1/9 bushel cartons      17.00        17.0  15.30
# 74       10  1 1/9 bushel cartons      15.00        15.0  13.50
# ...     ...                   ...        ...         ...    ...
# 1738      9    1/2 bushel cartons      15.00        15.0  30.00
# 1739      9    1/2 bushel cartons      13.75        15.0  28.75
# 1740      9    1/2 bushel cartons      10.75        15.0  25.75
# 1741      9    1/2 bushel cartons      12.00        12.0  24.00
# 1742      9    1/2 bushel cartons      12.00        12.0  24.00
#
# [415 rows x 5 columns]

# %%
# Displaying the prices as a bar chart grouped by month 
new_pumpkins.groupby(["Month"])["Price"].mean().plot(kind="bar")
plt.ylabel("Pumpkin Price")
# Out:
# Text(0, 0.5, 'Pumpkin Price')
